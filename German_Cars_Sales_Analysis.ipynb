# %% [markdown]
# # German Car Sales Analysis
# Author: Jadon Oliver

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
German_Car_Data = pd.read_csv('gcar_data.csv')
print(German_Car_Data)
# Out:
#        Unnamed: 0       brand                 model  color registration_date  \
# 0           75721        ford             Ford Kuga  black           05/2023
# 1           80184     hyundai           Hyundai i10  black           09/2018
# 2           19864        audi        Audi Q4 e-tron   grey           05/2021
# 3           76699       honda            Honda CR-V    red           07/2018
# 4           92991         kia          Kia Sportage  black           02/2023
# ...           ...         ...                   ...    ...               ...
# 99995        6265        audi               Audi A1   blue           05/2012
# 99996       54886        fiat              Fiat 500  black           12/2019
# 99997       76820       honda            Honda CR-V  brown           01/2019
# 99998         860  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020
# 99999       15795        audi               Audi A3  black           05/2018
#
#        year price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0      2023         38490      140      190         Automatic    Hybrid
# 1      2018         11555       49       67            Manual    Petrol
# 2      2021         48886      125      170         Automatic  Electric
# 3      2018         24490      114      155         Automatic    Petrol
# 4      2023         34990      110      150            Manual    Petrol
# ...     ...           ...      ...      ...               ...       ...
# 99995  2012         12599       90      122            Manual    Petrol
# 99996  2019          9999       51       69         Automatic    Petrol
# 99997  2019         24800      127      173            Manual    Petrol
# 99998  2020         22990      125      170         Automatic    Diesel
# 99999  2018         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                 5,4 l/100 km              124 g/km          100.0
# 1                 4,6 l/100 km              106 g/km        27782.0
# 2                          NaN                0 g/km         4247.0
# 3                 7,5 l/100 km              175 g/km        57000.0
# 4                 5,9 l/100 km              150 g/km         7500.0
# ...                        ...                   ...            ...
# 99995             5,3 l/100 km              126 g/km       148000.0
# 99996             5,2 l/100 km              120 g/km        31698.0
# 99997             6,3 l/100 km              143 g/km        77900.0
# 99998             5,5 l/100 km              145 g/km        52251.0
# 99999             5,3 l/100 km              120 g/km        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [100000 rows x 15 columns]

# %% [markdown]
# ## Dataset Overview
# Initial exploration of the dataset provided.

# %%
German_Car_Data.head()
# Out:
#    Unnamed: 0    brand           model  color registration_date  year  \
# 0       75721     ford       Ford Kuga  black           05/2023  2023
# 1       80184  hyundai     Hyundai i10  black           09/2018  2018
# 2       19864     audi  Audi Q4 e-tron   grey           05/2021  2021
# 3       76699    honda      Honda CR-V    red           07/2018  2018
# 4       92991      kia    Kia Sportage  black           02/2023  2023
#
#   price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0         38490      140      190         Automatic    Hybrid
# 1         11555       49       67            Manual    Petrol
# 2         48886      125      170         Automatic  Electric
# 3         24490      114      155         Automatic    Petrol
# 4         34990      110      150            Manual    Petrol
#
#   fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0             5,4 l/100 km              124 g/km          100.0
# 1             4,6 l/100 km              106 g/km        27782.0
# 2                      NaN                0 g/km         4247.0
# 3             7,5 l/100 km              175 g/km        57000.0
# 4             5,9 l/100 km              150 g/km         7500.0
#
#                                 offer_description
# 0  ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1             blue Trend,Viele Extras,Top-Zustand
# 2    35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3           2.0 Lifestyle Plus Automatik Navi FAP
# 4                    1.6 T 48V 2WD Spirit LED, WR

# %% [markdown]
# ### Preview: First 5 Rows

# %%
German_Car_Data.tail()
# Out:
#        Unnamed: 0       brand                 model  color registration_date  \
# 99995        6265        audi               Audi A1   blue           05/2012
# 99996       54886        fiat              Fiat 500  black           12/2019
# 99997       76820       honda            Honda CR-V  brown           01/2019
# 99998         860  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020
# 99999       15795        audi               Audi A3  black           05/2018
#
#        year price_in_euro power_kw power_ps transmission_type fuel_type  \
# 99995  2012         12599       90      122            Manual    Petrol
# 99996  2019          9999       51       69         Automatic    Petrol
# 99997  2019         24800      127      173            Manual    Petrol
# 99998  2020         22990      125      170         Automatic    Diesel
# 99999  2018         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 99995             5,3 l/100 km              126 g/km       148000.0
# 99996             5,2 l/100 km              120 g/km        31698.0
# 99997             6,3 l/100 km              143 g/km        77900.0
# 99998             5,5 l/100 km              145 g/km        52251.0
# 99999             5,3 l/100 km              120 g/km        30400.0
#
#                                       offer_description
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|

# %% [markdown]
# ### Preview: Last 5 Rows

# %%
German_Car_Data.describe()
# Out:
#           Unnamed: 0  mileage_in_km
# count  100000.000000   9.993200e+04
# mean    49999.500000   8.559891e+04
# std     28867.657797   7.929713e+04
# min         0.000000   0.000000e+00
# 25%     24999.750000   2.550000e+04
# 50%     49999.500000   6.800000e+04
# 75%     74999.250000   1.270000e+05
# max     99999.000000   3.800000e+06

# %% [markdown]
# ### Statistical Summary
# Using `describe()` to get summary statistics.

# %%
German_Car_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                100000 non-null  int64
#  1   brand                     100000 non-null  object
#  2   model                     100000 non-null  object
#  3   color                     99924 non-null   object
#  4   registration_date         99999 non-null   object
#  5   year                      100000 non-null  object
#  6   price_in_euro             100000 non-null  object
#  7   power_kw                  99925 non-null   object
#  8   power_ps                  99928 non-null   object
#  9   transmission_type         100000 non-null  object
#  10  fuel_type                 100000 non-null  object
#  11  fuel_consumption_l_100km  88761 non-null   object
#  12  fuel_consumption_g_km     100000 non-null  object
#  13  mileage_in_km             99932 non-null   float64
#  14  offer_description         100000 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 11.4+ MB

# %% [markdown]
# ### Dataset Dimensions and Column Info

# %% [markdown]
# ## Data Cleaning & Preparation

# %% [markdown]
# ### Removing Empty Columns

# %% [markdown]
# ### Dropping Unnamed Rows

# %%
German_Car_Data = German_Car_Data.iloc[:, 1:]

German_Car_Data.head()
# Out:
#      brand           model  color registration_date  year price_in_euro  \
# 0     ford       Ford Kuga  black           05/2023  2023         38490
# 1  hyundai     Hyundai i10  black           09/2018  2018         11555
# 2     audi  Audi Q4 e-tron   grey           05/2021  2021         48886
# 3    honda      Honda CR-V    red           07/2018  2018         24490
# 4      kia    Kia Sportage  black           02/2023  2023         34990
#
#   power_kw power_ps transmission_type fuel_type fuel_consumption_l_100km  \
# 0      140      190         Automatic    Hybrid             5,4 l/100 km
# 1       49       67            Manual    Petrol             4,6 l/100 km
# 2      125      170         Automatic  Electric                      NaN
# 3      114      155         Automatic    Petrol             7,5 l/100 km
# 4      110      150            Manual    Petrol             5,9 l/100 km
#
#   fuel_consumption_g_km  mileage_in_km  \
# 0              124 g/km          100.0
# 1              106 g/km        27782.0
# 2                0 g/km         4247.0
# 3              175 g/km        57000.0
# 4              150 g/km         7500.0
#
#                                 offer_description
# 0  ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1             blue Trend,Viele Extras,Top-Zustand
# 2    35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3           2.0 Lifestyle Plus Automatik Navi FAP
# 4                    1.6 T 48V 2WD Spirit LED, WR

# %% [markdown]
# ### Checking for Missing Values

# %%
German_Car_Data.isnull().sum()
# Out:
# brand                           0
# model                           0
# color                          76
# registration_date               1
# year                            0
# price_in_euro                   0
# power_kw                       75
# power_ps                       72
# transmission_type               0
# fuel_type                       0
# fuel_consumption_l_100km    11239
# fuel_consumption_g_km           0
# mileage_in_km                  68
# offer_description               0
# dtype: int64

# %% [markdown]
# ### turns any electric hybrid or ethanol vehicle's fuel consumption to 0 if the data is not present because it is not present in these rows

# %%
for item, row in German_Car_Data.iterrows():
    if pd.isnull(row['fuel_consumption_l_100km']) and row['fuel_type'] in ['Electric', 'Hydrogen', 'Ethanol']:
        German_Car_Data.at[item, 'fuel_consumption_l_100km'] = float(0)

display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#       price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0             38490      140      190         Automatic    Hybrid
# 1             11555       49       67            Manual    Petrol
# 2             48886      125      170         Automatic  Electric
# 3             24490      114      155         Automatic    Petrol
# 4             34990      110      150            Manual    Petrol
# ...             ...      ...      ...               ...       ...
# 99995         12599       90      122            Manual    Petrol
# 99996          9999       51       69         Automatic    Petrol
# 99997         24800      127      173            Manual    Petrol
# 99998         22990      125      170         Automatic    Diesel
# 99999         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                 5,4 l/100 km              124 g/km          100.0
# 1                 4,6 l/100 km              106 g/km        27782.0
# 2                          0.0                0 g/km         4247.0
# 3                 7,5 l/100 km              175 g/km        57000.0
# 4                 5,9 l/100 km              150 g/km         7500.0
# ...                        ...                   ...            ...
# 99995             5,3 l/100 km              126 g/km       148000.0
# 99996             5,2 l/100 km              120 g/km        31698.0
# 99997             6,3 l/100 km              143 g/km        77900.0
# 99998             5,5 l/100 km              145 g/km        52251.0
# 99999             5,3 l/100 km              120 g/km        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [100000 rows x 14 columns]

# %% [markdown]
# ### Excludes any rows with the fuel type columns as other or unkown because that data is less useful for the analysis

# %%
German_Car_Data = German_Car_Data[(German_Car_Data['fuel_type'] != 'Unknown') & (German_Car_Data['fuel_type'] != 'Other')]

display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#       price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0             38490      140      190         Automatic    Hybrid
# 1             11555       49       67            Manual    Petrol
# 2             48886      125      170         Automatic  Electric
# 3             24490      114      155         Automatic    Petrol
# 4             34990      110      150            Manual    Petrol
# ...             ...      ...      ...               ...       ...
# 99995         12599       90      122            Manual    Petrol
# 99996          9999       51       69         Automatic    Petrol
# 99997         24800      127      173            Manual    Petrol
# 99998         22990      125      170         Automatic    Diesel
# 99999         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                 5,4 l/100 km              124 g/km          100.0
# 1                 4,6 l/100 km              106 g/km        27782.0
# 2                          0.0                0 g/km         4247.0
# 3                 7,5 l/100 km              175 g/km        57000.0
# 4                 5,9 l/100 km              150 g/km         7500.0
# ...                        ...                   ...            ...
# 99995             5,3 l/100 km              126 g/km       148000.0
# 99996             5,2 l/100 km              120 g/km        31698.0
# 99997             6,3 l/100 km              143 g/km        77900.0
# 99998             5,5 l/100 km              145 g/km        52251.0
# 99999             5,3 l/100 km              120 g/km        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [99871 rows x 14 columns]

# %% [markdown]
# ### Goes through each row of fuel_consumption_l_100km and changes it to floats so the data can be used

# %%
for index, row in German_Car_Data.iterrows():
    value = row['fuel_consumption_l_100km']
    if isinstance(value, float):
        continue
    elif 'l/100 km' in str(value):
        value = str(value).replace(' l/100 km', '').replace(',', '.')
        try:
            German_Car_Data.at[index, 'fuel_consumption_l_100km'] = float(value)
        except ValueError:
            German_Car_Data.at[index, 'fuel_consumption_l_100km'] = None
    else:
        German_Car_Data.at[index, 'fuel_consumption_l_100km'] = None

display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#       price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0             38490      140      190         Automatic    Hybrid
# 1             11555       49       67            Manual    Petrol
# 2             48886      125      170         Automatic  Electric
# 3             24490      114      155         Automatic    Petrol
# 4             34990      110      150            Manual    Petrol
# ...             ...      ...      ...               ...       ...
# 99995         12599       90      122            Manual    Petrol
# 99996          9999       51       69         Automatic    Petrol
# 99997         24800      127      173            Manual    Petrol
# 99998         22990      125      170         Automatic    Diesel
# 99999         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                          5.4              124 g/km          100.0
# 1                          4.6              106 g/km        27782.0
# 2                          0.0                0 g/km         4247.0
# 3                          7.5              175 g/km        57000.0
# 4                          5.9              150 g/km         7500.0
# ...                        ...                   ...            ...
# 99995                      5.3              126 g/km       148000.0
# 99996                      5.2              120 g/km        31698.0
# 99997                      6.3              143 g/km        77900.0
# 99998                      5.5              145 g/km        52251.0
# 99999                      5.3              120 g/km        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [99871 rows x 14 columns]

# %% [markdown]
# ### Goes through each row of fuel_consumption_g_km and changes it to floats so the data can be used

# %%
for index, row in German_Car_Data.iterrows():
    value = row['fuel_consumption_g_km']  # Accessing only the 'fuel_consumption_g_km' column
    if isinstance(value, float):
        continue
    elif 'g/km' in str(value):
        value = str(value).replace(' g/km', '').replace(',', '.')
        try:
            German_Car_Data.at[index, 'fuel_consumption_g_km'] = float(value)
        except ValueError:
            German_Car_Data.at[index, 'fuel_consumption_g_km'] = None
    else:
        German_Car_Data.at[index, 'fuel_consumption_g_km'] = None

display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#       price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0             38490      140      190         Automatic    Hybrid
# 1             11555       49       67            Manual    Petrol
# 2             48886      125      170         Automatic  Electric
# 3             24490      114      155         Automatic    Petrol
# 4             34990      110      150            Manual    Petrol
# ...             ...      ...      ...               ...       ...
# 99995         12599       90      122            Manual    Petrol
# 99996          9999       51       69         Automatic    Petrol
# 99997         24800      127      173            Manual    Petrol
# 99998         22990      125      170         Automatic    Diesel
# 99999         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                          5.4                 124.0          100.0
# 1                          4.6                 106.0        27782.0
# 2                          0.0                   0.0         4247.0
# 3                          7.5                 175.0        57000.0
# 4                          5.9                 150.0         7500.0
# ...                        ...                   ...            ...
# 99995                      5.3                 126.0       148000.0
# 99996                      5.2                 120.0        31698.0
# 99997                      6.3                 143.0        77900.0
# 99998                      5.5                 145.0        52251.0
# 99999                      5.3                 120.0        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [99871 rows x 14 columns]

# %% [markdown]
# ### gets rid of any columns in fuel consumption l 100km that are not a float

# %%
rows_to_keep = []

for index, row in German_Car_Data.iterrows():
    if isinstance(row['fuel_consumption_l_100km'], float):
        rows_to_keep.append(index)

German_Car_Data = German_Car_Data.loc[rows_to_keep]

display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#       price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0             38490      140      190         Automatic    Hybrid
# 1             11555       49       67            Manual    Petrol
# 2             48886      125      170         Automatic  Electric
# 3             24490      114      155         Automatic    Petrol
# 4             34990      110      150            Manual    Petrol
# ...             ...      ...      ...               ...       ...
# 99995         12599       90      122            Manual    Petrol
# 99996          9999       51       69         Automatic    Petrol
# 99997         24800      127      173            Manual    Petrol
# 99998         22990      125      170         Automatic    Diesel
# 99999         21900      110      150            Manual    Petrol
#
#       fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                          5.4                 124.0          100.0
# 1                          4.6                 106.0        27782.0
# 2                          0.0                   0.0         4247.0
# 3                          7.5                 175.0        57000.0
# 4                          5.9                 150.0         7500.0
# ...                        ...                   ...            ...
# 99995                      5.3                 126.0       148000.0
# 99996                      5.2                 120.0        31698.0
# 99997                      6.3                 143.0        77900.0
# 99998                      5.5                 145.0        52251.0
# 99999                      5.3                 120.0        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [99087 rows x 14 columns]

# %% [markdown]
# ### Because this dataset is so large and is mostly input from users, drop na to make sure that all of the data available is clean data that will help me analyze the dataset. Also changes some row types to the proper types

# %%
German_Car_Data.dropna(inplace=True)

German_Car_Data['price_in_euro'] = German_Car_Data['price_in_euro'].astype(int)

German_Car_Data['power_kw'] = German_Car_Data['power_kw'].astype(int)

German_Car_Data['power_ps'] = German_Car_Data['power_kw'].astype(int)

German_Car_Data['fuel_consumption_l_100km'] = German_Car_Data['fuel_consumption_l_100km'].astype(float)

German_Car_Data['fuel_consumption_g_km'] = German_Car_Data['fuel_consumption_g_km'].astype(float)

display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#        price_in_euro  power_kw  power_ps transmission_type fuel_type  \
# 0              38490       140       140         Automatic    Hybrid
# 1              11555        49        49            Manual    Petrol
# 2              48886       125       125         Automatic  Electric
# 3              24490       114       114         Automatic    Petrol
# 4              34990       110       110            Manual    Petrol
# ...              ...       ...       ...               ...       ...
# 99995          12599        90        90            Manual    Petrol
# 99996           9999        51        51         Automatic    Petrol
# 99997          24800       127       127            Manual    Petrol
# 99998          22990       125       125         Automatic    Diesel
# 99999          21900       110       110            Manual    Petrol
#
#        fuel_consumption_l_100km  fuel_consumption_g_km  mileage_in_km  \
# 0                           5.4                  124.0          100.0
# 1                           4.6                  106.0        27782.0
# 2                           0.0                    0.0         4247.0
# 3                           7.5                  175.0        57000.0
# 4                           5.9                  150.0         7500.0
# ...                         ...                    ...            ...
# 99995                       5.3                  126.0       148000.0
# 99996                       5.2                  120.0        31698.0
# 99997                       6.3                  143.0        77900.0
# 99998                       5.5                  145.0        52251.0
# 99999                       5.3                  120.0        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [79179 rows x 14 columns]

# %% [markdown]
# ### drops all duplicate columns in the code

# %%
German_Car_Data.drop_duplicates(inplace=True)

# %%
German_Car_Data.describe()
# Out:
#        price_in_euro      power_kw      power_ps  fuel_consumption_l_100km  \
# count   7.665400e+04  76654.000000  76654.000000              76654.000000
# mean    2.893513e+04    137.583088    137.583088                  6.153817
# std     4.686165e+04     79.727498     79.727498                  2.511089
# min     2.500000e+02      5.000000      5.000000                  0.000000
# 25%     1.299000e+04     88.000000     88.000000                  4.900000
# 50%     2.049000e+04    110.000000    110.000000                  5.800000
# 75%     3.199000e+04    154.000000    154.000000                  6.900000
# max     5.890500e+06    735.000000    735.000000                141.000000
#
#        fuel_consumption_g_km  mileage_in_km
# count           76654.000000   7.665400e+04
# mean              148.418228   8.302349e+04
# std                55.171547   7.618236e+04
# min                 0.000000   0.000000e+00
# 25%               120.000000   2.590000e+04
# 50%               140.000000   6.668000e+04
# 75%               170.000000   1.221168e+05
# max               999.000000   3.800000e+06

# %%
German_Car_Data.head()
# Out:
#      brand           model  color registration_date  year  price_in_euro  \
# 0     ford       Ford Kuga  black           05/2023  2023          38490
# 1  hyundai     Hyundai i10  black           09/2018  2018          11555
# 2     audi  Audi Q4 e-tron   grey           05/2021  2021          48886
# 3    honda      Honda CR-V    red           07/2018  2018          24490
# 4      kia    Kia Sportage  black           02/2023  2023          34990
#
#    power_kw  power_ps transmission_type fuel_type  fuel_consumption_l_100km  \
# 0       140       140         Automatic    Hybrid                       5.4
# 1        49        49            Manual    Petrol                       4.6
# 2       125       125         Automatic  Electric                       0.0
# 3       114       114         Automatic    Petrol                       7.5
# 4       110       110            Manual    Petrol                       5.9
#
#    fuel_consumption_g_km  mileage_in_km  \
# 0                  124.0          100.0
# 1                  106.0        27782.0
# 2                    0.0         4247.0
# 3                  175.0        57000.0
# 4                  150.0         7500.0
#
#                                 offer_description
# 0  ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1             blue Trend,Viele Extras,Top-Zustand
# 2    35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3           2.0 Lifestyle Plus Automatik Navi FAP
# 4                    1.6 T 48V 2WD Spirit LED, WR

# %%
German_Car_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76654 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   brand                     76654 non-null  object
#  1   model                     76654 non-null  object
#  2   color                     76654 non-null  object
#  3   registration_date         76654 non-null  object
#  4   year                      76654 non-null  object
#  5   price_in_euro             76654 non-null  int32
#  6   power_kw                  76654 non-null  int32
#  7   power_ps                  76654 non-null  int32
#  8   transmission_type         76654 non-null  object
#  9   fuel_type                 76654 non-null  object
#  10  fuel_consumption_l_100km  76654 non-null  float64
#  11  fuel_consumption_g_km     76654 non-null  float64
#  12  mileage_in_km             76654 non-null  float64
#  13  offer_description         76654 non-null  object
# dtypes: float64(3), int32(3), object(8)
# memory usage: 7.9+ MB

# %%
display(German_Car_Data)
# Out:
#             brand                 model  color registration_date  year  \
# 0            ford             Ford Kuga  black           05/2023  2023
# 1         hyundai           Hyundai i10  black           09/2018  2018
# 2            audi        Audi Q4 e-tron   grey           05/2021  2021
# 3           honda            Honda CR-V    red           07/2018  2018
# 4             kia          Kia Sportage  black           02/2023  2023
# ...           ...                   ...    ...               ...   ...
# 99995        audi               Audi A1   blue           05/2012  2012
# 99996        fiat              Fiat 500  black           12/2019  2019
# 99997       honda            Honda CR-V  brown           01/2019  2019
# 99998  alfa-romeo  Alfa Romeo Giulietta   grey           12/2020  2020
# 99999        audi               Audi A3  black           05/2018  2018
#
#        price_in_euro  power_kw  power_ps transmission_type fuel_type  \
# 0              38490       140       140         Automatic    Hybrid
# 1              11555        49        49            Manual    Petrol
# 2              48886       125       125         Automatic  Electric
# 3              24490       114       114         Automatic    Petrol
# 4              34990       110       110            Manual    Petrol
# ...              ...       ...       ...               ...       ...
# 99995          12599        90        90            Manual    Petrol
# 99996           9999        51        51         Automatic    Petrol
# 99997          24800       127       127            Manual    Petrol
# 99998          22990       125       125         Automatic    Diesel
# 99999          21900       110       110            Manual    Petrol
#
#        fuel_consumption_l_100km  fuel_consumption_g_km  mileage_in_km  \
# 0                           5.4                  124.0          100.0
# 1                           4.6                  106.0        27782.0
# 2                           0.0                    0.0         4247.0
# 3                           7.5                  175.0        57000.0
# 4                           5.9                  150.0         7500.0
# ...                         ...                    ...            ...
# 99995                       5.3                  126.0       148000.0
# 99996                       5.2                  120.0        31698.0
# 99997                       6.3                  143.0        77900.0
# 99998                       5.5                  145.0        52251.0
# 99999                       5.3                  120.0        30400.0
#
#                                       offer_description
# 0        ST-Line Hybrid Adapt.LED+Head-Up-Display Klima
# 1                   blue Trend,Viele Extras,Top-Zustand
# 2          35 e-tron S line/Matrix/Pano/ACC/SONOS/LM 21
# 3                 2.0 Lifestyle Plus Automatik Navi FAP
# 4                          1.6 T 48V 2WD Spirit LED, WR
# ...                                                 ...
# 99995        Ambition TFSI Navi/Leder/SHZ/PTS/KETTE NEU
# 99996                       1.2 Lounge +Automatik + PDC
# 99997  1.5T 2WD Elegance * 1. Hand * 24 Mon. Garantie *
# 99998            Lusso Ti 2.0 JTDM 16V Xenon Leder Navi
# 99999         Sportback1.5 Sport|VIRTUAL|NAVI|LED|30KM|
#
# [76654 rows x 14 columns]

# %% [markdown]
# # Question #1
# ### Do manual or automatic vehicles get better mileage? Is there a difference, and if so, which car is more gas-efficient?

# %%
# Calculate the average fuel consumption for manual and automatic transmission types
avg_fuel_consumption = German_Car_Data.groupby('transmission_type')['fuel_consumption_l_100km'].mean()
print(avg_fuel_consumption[['Manual', 'Automatic']])
# Out:
# transmission_type
# Manual       5.767520
# Automatic    6.494057
# Name: fuel_consumption_l_100km, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=avg_fuel_consumption.index, y=avg_fuel_consumption.values, palette='pastel')
plt.title('Average Fuel Consumption by Transmission Type')
plt.ylabel('Fuel Consumption (L/100km)')
plt.xlabel('Transmission Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Automatic transmissions on average consume slightly more fuel than cars with manual transmissions. It is not a very noticeable amount but if a consumer wanted to minimize their fuel consumption, they should get a car with a manual transmission.

# %% [markdown]
# # Question #2
# ### Is there a fuel type that is the most efficient for gas mileage, such as a Hybrid, Petrol, Diesel, or Petrol?

# %%
# Calculate the average fuel consumption for each fuel type
avg_fuel_by_type = German_Car_Data.groupby('fuel_type')['fuel_consumption_l_100km'].mean().sort_values()
print(avg_fuel_by_type)
# Out:
# fuel_type
# Electric         0.000000
# Hydrogen         0.000000
# Ethanol          2.720000
# Hybrid           3.525222
# Diesel Hybrid    5.403419
# Diesel           5.643297
# Petrol           6.830958
# LPG              8.133690
# CNG              8.700000
# Name: fuel_consumption_l_100km, dtype: float64

# %%
# Plot: Average fuel consumption by fuel type
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_fuel_by_type.index, y=avg_fuel_by_type.values, palette='Set2')
plt.title('Average Fuel Consumption by Fuel Type')
plt.ylabel('Fuel Consumption (L/100km)')
plt.xlabel('Fuel Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Electric and Hydrogen cars have the best and lowest average fuel consumptions, followed by ethanol then hybrid vehicles. CNG vehicles had the highest fuel consumption on average and would get the worst gas mileage out of all of the fuel types.

# %% [markdown]
# # Question #3
# ### Which vehicle fuel type has the most power?

# %%
# Calculate the average power in kW for each fuel type
avg_power_by_fuel_type = German_Car_Data.groupby('fuel_type')['power_kw'].mean().sort_values(ascending=False)
print(avg_power_by_fuel_type)
# Out:
# fuel_type
# Ethanol          198.600000
# Electric         154.520632
# Diesel Hybrid    145.888889
# Hybrid           143.271702
# Diesel           138.345166
# Petrol           136.318026
# LPG              127.960784
# Hydrogen         116.000000
# CNG               82.000000
# Name: power_kw, dtype: float64

# %%
# Average power by fuel type
plt.figure(figsize=(12, 6))
avg_power_by_fuel_type = German_Car_Data.groupby('fuel_type')['power_kw'].mean().sort_values(ascending=False)
sns.barplot(x=avg_power_by_fuel_type.index, y=avg_power_by_fuel_type.values, palette='coolwarm')
plt.title('Average Power by Fuel Type (kW)')
plt.xlabel('Fuel Type')
plt.ylabel('Average Power (kW)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Ethanol vehicles got the most power significantly, followed by electric vehicles. CNG vehicles have the least power and hydrogen cars have the second least power out of all of the fuel types.

# %% [markdown]
# # Question #4
# ### Average Price for cars in different ranges of gas mileage (0-10000, 10000-25000, 25000-50000, 50000-100000, 100000-150000,1500000-200000, 200000+)

# %%
# Define mileage and calculate the average price within each
mileage = [0, 10000, 25000, 50000, 100000, 150000, 200000, float('inf')]
labels = ['0-10,000 km', '10,001-25,000 km', '25,001-50,000 km', '50,001-100,000 km', '100,001-150,000 km', '150,001-200,000 km', '200,000+ km']
German_Car_Data['mileage_range'] = pd.cut(German_Car_Data['mileage_in_km'], bins=mileage, labels=labels)
avg_price_by_mileage = German_Car_Data.groupby('mileage_range')['price_in_euro'].mean()
print(avg_price_by_mileage)
# Out:
# mileage_range
# 0-10,000 km           55977.179074
# 10,001-25,000 km      41036.774232
# 25,001-50,000 km      31891.832038
# 50,001-100,000 km     24794.737328
# 100,001-150,000 km    17972.358411
# 150,001-200,000 km    13414.344668
# 200,000+ km            8900.216087
# Name: price_in_euro, dtype: float64

# %%
# Average price within each mileage range
avg_price_by_mileage = German_Car_Data.groupby('mileage_range')['price_in_euro'].mean()
plt.figure(figsize=(12, 6))
plt.plot(avg_price_by_mileage.index, avg_price_by_mileage, marker='o', linestyle='-', color='darkgreen')
plt.title('Average Price by Mileage Range')
plt.xlabel('Mileage Range (km)')
plt.ylabel('Average Price in Euro (€)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Looking at the graph and numerical data, the higher mileage the car has, the less expensive the car is to buy on average. Lower mileage cars are generally more expensive.

# %% [markdown]
# # Question #5
# ### Is there a correlation between the car's horsepower (Ps) and its price?

# %%
# Scatter plot for Price vs. Horsepower in PS
plt.figure(figsize=(10, 6))
ax2 = sns.regplot(x='power_ps', y='price_in_euro', data=German_Car_Data, scatter_kws={'alpha':0.5}, line_kws={'color': 'blue'})
ax2.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x} PS'))
ax2.yaxis.set_major_formatter(ticker.StrMethodFormatter('€{x}'))
plt.title('Price vs. Horsepower (PS)')
plt.xlabel('Horsepower (PS)')
plt.ylabel('Price in Euro')
plt.ylim(0, 1500000)  # Set y-axis limit to 1,500,000
plt.grid(True)
plt.show()

# %% [markdown]
# ### The graph shows that generally, the cars with higher horsepower are more expensive than cars with lower horsepower through the regression line. You can also see this with the density of the points go up on the y axis as they progress on the x axis
